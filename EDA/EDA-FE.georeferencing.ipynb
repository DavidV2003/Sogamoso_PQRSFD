# %% [markdown]
# # FE: Georeferencing

# %%
#Run only if there are errors related to missing packages
#!pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
import googlemaps
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import pingouin as pg

# %% [markdown]
# Since the only datasets with info are the one from "aseguramiento" and the PDFs, we will only work with that info.

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# We prepare the data from "aseguramiento". Note that we build the column "DIRECCION_COMPLETA" that will be used by the Geocoder.

# %%
# Importing the df from "aseguramiento"
aseguramiento=pd.read_csv('/datasets/gdrive/DS4A - Team Project/data/aseguramiento.v3/aseguramiento_final.csv', encoding="latin-1")

#We clean the names of the column
#aseguramiento.columns = [c.replace(' ', '_') for c in df.columns]

#We create a new column with the address ready for the Geocoder
aseguramiento["DIRECCION_COMPLETA"] = aseguramiento['DIRECCION'].str.strip() +", "+ aseguramiento["MUNICIPIO"] +", "+ aseguramiento["DEPARTAMENTO"] +", "+ aseguramiento["PAIS"]

aseguramiento
# Out:
#             RADICADO                       FECHA  \
# 0     20191700062932  2019-05-06 14:24:20.476704
# 1     20191700063412  2019-05-06 16:14:32.807325
# 2     20191700063562  2019-05-06 17:20:00.604149
# 3     20191700063762  2019-05-07 10:48:55.942940
# 4     20191700063922  2019-05-07 11:44:11.598638
# ...              ...                         ...
# 1956  20191700061802  2019-05-03 09:46:20.619884
# 1957  20191700061812  2019-05-03 09:48:27.418469
# 1958  20191700062142  2019-05-03 14:31:18.900281
# 1959  20191700062312  2019-05-03 15:30:18.361842
# 1960  20191700062482  2019-05-06 09:52:22.710970
#
#                                                  ASUNTO  \
# 0                    INFORMACION DE CAMBIO DE DIRECCION
# 1     DESCARGOS POR PROCESO SANCIONATORIO Y CARGOS D...
# 2       PD-1149\r\nRADICADO 1039 DE 24 DE ABRIL DE 2019
# 3     TRASLADO DENUNCIA CON RADICADO INVIMA No. 2019...
# 4                                SOLICITUD INFORMACION
# ...                                                 ...
# 1956  ACCION DE TUTELA No. 2019-0017\r\nACTE: MARIA ...
# 1957  ACCION DE TUTELA No. 2019-0019\r\nACTE: MARIA ...
# 1958                         SOLICITUD VISTA SANITARIA
# 1959  RESPUESTA A DERECHO DE PETICION RADICADO INVIM...
# 1960                        SOLICITUD VISITA SANITARIA
#
#                                               DIRECCION MUNICIPIO  \
# 0                                 CARRERA 14 No. 13-82   SOGAMOSO
# 1              KRA 10 A NÂ° 53-68 JUAN JOSE RONDON       SOGAMOSO
# 2     CALLE 15 NO. 11-79 OFICINA 302 EDIFICIO EL PIN...  SOGAMOSO
# 3                                      CRA 10 N 64-28      BOGOTA
# 4                          CARRERA 12 No. 16-31 PISO 3   SOGAMOSO
# ...                                                 ...       ...
# 1956                         CALLE 11 No. 9-30 OFC 202   SOGAMOSO
# 1957                          CALLE 11 No. 9-30 OFC 202  SOGAMOSO
# 1958                        CARRERA 13 No. 4-68 INT. 5   SOGAMOSO
# 1959                                   CRA 10 N 64-28      BOGOTA
# 1960                              VEREDA SANTA HELENA    SOGAMOSO
#
#      DEPARTAMENTO      PAIS                                 DIRECCION_COMPLETA
# 0          BOYACA  COLOMBIA   CARRERA 14 No. 13-82, SOGAMOSO, BOYACA, COLOMBIA
# 1          BOYACA  COLOMBIA  KRA 10 A NÂ° 53-68 JUAN JOSE RONDON, SOGAMOSO,...
# 2          BOYACA  COLOMBIA  CALLE 15 NO. 11-79 OFICINA 302 EDIFICIO EL PIN...
# 3            D.C.  COLOMBIA             CRA 10 N 64-28, BOGOTA, D.C., COLOMBIA
# 4          BOYACA  COLOMBIA  CARRERA 12 No. 16-31 PISO 3, SOGAMOSO, BOYACA,...
# ...           ...       ...                                                ...
# 1956       BOYACA  COLOMBIA  CALLE 11 No. 9-30 OFC 202, SOGAMOSO, BOYACA, C...
# 1957       BOYACA  COLOMBIA  CALLE 11 No. 9-30 OFC 202, SOGAMOSO, BOYACA, C...
# 1958       BOYACA  COLOMBIA  CARRERA 13 No. 4-68 INT. 5, SOGAMOSO, BOYACA, ...
# 1959         D.C.  COLOMBIA             CRA 10 N 64-28, BOGOTA, D.C., COLOMBIA
# 1960       BOYACA  COLOMBIA    VEREDA SANTA HELENA, SOGAMOSO, BOYACA, COLOMBIA
#
# [1961 rows x 8 columns]

# %% [markdown]
# Now, we prepare the data from the PDFs. Note that we also create the column "DIRECCION_COMPLETA" that will be used by the Geocoder.

# %%
# Importing the df from PDFs
PDF=pd.read_csv('/datasets/gdrive/DS4A - Team Project/data/PDF_Orfeo.v3/data_pdfs_orfeo.csv', encoding="latin-1")
PDF.columns = ["RADICADO","FECHA","ASUNTO","PAIS","DIRECCION","TEXTO_PQRSDF"]

# We have verified that all entries in the PDFs are from the same place
PDF["MUNICIPIO"] = "SOGAMOSO"
PDF["DEPARTAMENTO"] = "BOYACA"

# We delete a dot at the end of the strings in that column
PDF["DIRECCION"] = PDF["DIRECCION"].str[:-1]

# We create the new column with the complete address
PDF["DIRECCION_COMPLETA"] = PDF['DIRECCION'].str.strip() +", "+ PDF["PAIS"]

PDF
# Out:
#            RADICADO                    FECHA  \
# 0    20182000001012  27 - 10 - 2018 11:09:51
# 1    20182000001072  27 - 10 - 2018 11:32:35
# 2    20182000001312  11 - 12 - 2018 01:19:06
# 3    20182000000792  27 - 09 - 2018 03:38:10
# 4    20182000000172  15 - 08 - 2018 02:55:09
# ..              ...                      ...
# 756  20222000000772  13 - 05 - 2022 06:32:54
# 757  20222000000592  22 - 04 - 2022 11:18:46
# 758  20222000000452  18 - 03 - 2022 06:14:08
# 759  20222000000712  13 - 05 - 2022 05:50:49
# 760  20222000000212  22 - 02 - 2022 04:03:51
#
#                                                 ASUNTO      PAIS  \
# 0                                      AUTORIZACIÓN CX  COLOMBIA
# 1                               AUTORIZACIÓN AYUDAS DX  COLOMBIA
# 2                                         MEDICAMENTOS  COLOMBIA
# 3    QUE LA EPS LE BRINDE UNA ATENCIÓN INTEGRAL  YA...  COLOMBIA
# 4                                   ASIGNACION DE CITA  COLOMBIA
# ..                                                 ...       ...
# 756                        INOPORTUNIDAD-EN-LA-ENTREGA  COLOMBIA
# 757                       INOPORTUNIDAD-EN-EL-SERVICIO  COLOMBIA
# 758                       INOPORTUNIDAD-EN-EL-SERVICIO  COLOMBIA
# 759                       INOPORTUNIDAD-EN-EL-SERVICIO  COLOMBIA
# 760                       INOPORTUNIDAD-EN-EL-SERVICIO  COLOMBIA
#
#                                         DIRECCION  \
# 0            CARRERA 34 # 15-145 SOGAMOSO, BOYACA
# 1           CALLE 58 DIAGONAL 11 SOGAMOSO, BOYACA
# 2           CARRERA 19 # 11 A 06 SOGAMOSO, BOYACA
# 3             CALLE 13 No 229-15 SOGAMOSO, BOYACA
# 4                calle 7A 14A-02 SOGAMOSO, BOYACA
# ..                                            ...
# 756           CALLE-47-No.11A-27 SOGAMOSO, BOYACA
# 757           CARRERA-20-No.7-31 SOGAMOSO, BOYACA
# 758             CARRERA-21-15-48 SOGAMOSO, BOYACA
# 759  CALLE-46-No.12-D-61-CASA-51 SOGAMOSO, BOYACA
# 760              VEREDA-EL-CIDAL SOGAMOSO, BOYACA
#
#                                           TEXTO_PQRSDF MUNICIPIO DEPARTAMENTO  \
# 0                     LA EPS NO AUTORIZA CX DE CADERAS  SOGAMOSO       BOYACA
# 1      LA EPS NO AUTORIZA LABORATORIOS,CONTROL POR CX.  SOGAMOSO       BOYACA
# 2          LA EPS NO AUTORIZA NMEDICAMENTO DABIGATRAN.  SOGAMOSO       BOYACA
# 3    SOLICITO  A  LA  EPS  ME  PRESTE  MANEJO  DOMI...  SOGAMOSO       BOYACA
# 4    LLEVO ESPERANDO CITA EN FAMEDIC Y OTORRINONLOG...  SOGAMOSO       BOYACA
# ..                                                 ...       ...          ...
# 756  USUARIA-QUE-SOLICITA-AGILIDAD-EN-LA-ENTREGA-DE...  SOGAMOSO       BOYACA
# 757  USUARIA-MENOR-DE-EDAD-QUE-MANIFIESTA-INCONFORM...  SOGAMOSO       BOYACA
# 758  USUARIA-QUE-MANIFIESTA-INCONFORMIDAD-EN-LA-ENT...  SOGAMOSO       BOYACA
# 759  PADRE-DEL-MENOR-SOLICITA-QUE-EL-MEDICAMENTO-FO...  SOGAMOSO       BOYACA
# 760  LAS-SEÑORA-MADRE-DE-LA-MENOR-DE-EDAD-AFILIADA-...  SOGAMOSO       BOYACA
#
#                                     DIRECCION_COMPLETA
# 0       CARRERA 34 # 15-145 SOGAMOSO, BOYACA, COLOMBIA
# 1      CALLE 58 DIAGONAL 11 SOGAMOSO, BOYACA, COLOMBIA
# 2      CARRERA 19 # 11 A 06 SOGAMOSO, BOYACA, COLOMBIA
# 3        CALLE 13 No 229-15 SOGAMOSO, BOYACA, COLOMBIA
# 4           calle 7A 14A-02 SOGAMOSO, BOYACA, COLOMBIA
# ..                                                 ...
# 756      CALLE-47-No.11A-27 SOGAMOSO, BOYACA, COLOMBIA
# 757      CARRERA-20-No.7-31 SOGAMOSO, BOYACA, COLOMBIA
# 758        CARRERA-21-15-48 SOGAMOSO, BOYACA, COLOMBIA
# 759  CALLE-46-No.12-D-61-CASA-51 SOGAMOSO, BOYACA, ...
# 760         VEREDA-EL-CIDAL SOGAMOSO, BOYACA, COLOMBIA
#
# [761 rows x 9 columns]

# %% [markdown]
# Finally, we concatenate the two datasets.

# %%
df = pd.concat([PDF, aseguramiento], axis=0, ignore_index=True, verify_integrity=True)
df
# Out:
#             RADICADO                       FECHA  \
# 0     20182000001012     27 - 10 - 2018 11:09:51
# 1     20182000001072     27 - 10 - 2018 11:32:35
# 2     20182000001312     11 - 12 - 2018 01:19:06
# 3     20182000000792     27 - 09 - 2018 03:38:10
# 4     20182000000172     15 - 08 - 2018 02:55:09
# ...              ...                         ...
# 2717  20191700061802  2019-05-03 09:46:20.619884
# 2718  20191700061812  2019-05-03 09:48:27.418469
# 2719  20191700062142  2019-05-03 14:31:18.900281
# 2720  20191700062312  2019-05-03 15:30:18.361842
# 2721  20191700062482  2019-05-06 09:52:22.710970
#
#                                                  ASUNTO      PAIS  \
# 0                                       AUTORIZACIÓN CX  COLOMBIA
# 1                                AUTORIZACIÓN AYUDAS DX  COLOMBIA
# 2                                          MEDICAMENTOS  COLOMBIA
# 3     QUE LA EPS LE BRINDE UNA ATENCIÓN INTEGRAL  YA...  COLOMBIA
# 4                                    ASIGNACION DE CITA  COLOMBIA
# ...                                                 ...       ...
# 2717  ACCION DE TUTELA No. 2019-0017\r\nACTE: MARIA ...  COLOMBIA
# 2718  ACCION DE TUTELA No. 2019-0019\r\nACTE: MARIA ...  COLOMBIA
# 2719                         SOLICITUD VISTA SANITARIA   COLOMBIA
# 2720  RESPUESTA A DERECHO DE PETICION RADICADO INVIM...  COLOMBIA
# 2721                        SOLICITUD VISITA SANITARIA   COLOMBIA
#
#                                   DIRECCION  \
# 0      CARRERA 34 # 15-145 SOGAMOSO, BOYACA
# 1     CALLE 58 DIAGONAL 11 SOGAMOSO, BOYACA
# 2     CARRERA 19 # 11 A 06 SOGAMOSO, BOYACA
# 3       CALLE 13 No 229-15 SOGAMOSO, BOYACA
# 4          calle 7A 14A-02 SOGAMOSO, BOYACA
# ...                                     ...
# 2717             CALLE 11 No. 9-30 OFC 202
# 2718              CALLE 11 No. 9-30 OFC 202
# 2719            CARRERA 13 No. 4-68 INT. 5
# 2720                       CRA 10 N 64-28
# 2721                  VEREDA SANTA HELENA
#
#                                            TEXTO_PQRSDF MUNICIPIO  \
# 0                      LA EPS NO AUTORIZA CX DE CADERAS  SOGAMOSO
# 1       LA EPS NO AUTORIZA LABORATORIOS,CONTROL POR CX.  SOGAMOSO
# 2           LA EPS NO AUTORIZA NMEDICAMENTO DABIGATRAN.  SOGAMOSO
# 3     SOLICITO  A  LA  EPS  ME  PRESTE  MANEJO  DOMI...  SOGAMOSO
# 4     LLEVO ESPERANDO CITA EN FAMEDIC Y OTORRINONLOG...  SOGAMOSO
# ...                                                 ...       ...
# 2717                                                NaN  SOGAMOSO
# 2718                                                NaN  SOGAMOSO
# 2719                                                NaN  SOGAMOSO
# 2720                                                NaN    BOGOTA
# 2721                                                NaN  SOGAMOSO
#
#      DEPARTAMENTO                                 DIRECCION_COMPLETA
# 0          BOYACA     CARRERA 34 # 15-145 SOGAMOSO, BOYACA, COLOMBIA
# 1          BOYACA    CALLE 58 DIAGONAL 11 SOGAMOSO, BOYACA, COLOMBIA
# 2          BOYACA    CARRERA 19 # 11 A 06 SOGAMOSO, BOYACA, COLOMBIA
# 3          BOYACA      CALLE 13 No 229-15 SOGAMOSO, BOYACA, COLOMBIA
# 4          BOYACA         calle 7A 14A-02 SOGAMOSO, BOYACA, COLOMBIA
# ...           ...                                                ...
# 2717       BOYACA  CALLE 11 No. 9-30 OFC 202, SOGAMOSO, BOYACA, C...
# 2718       BOYACA  CALLE 11 No. 9-30 OFC 202, SOGAMOSO, BOYACA, C...
# 2719       BOYACA  CARRERA 13 No. 4-68 INT. 5, SOGAMOSO, BOYACA, ...
# 2720         D.C.             CRA 10 N 64-28, BOGOTA, D.C., COLOMBIA
# 2721       BOYACA    VEREDA SANTA HELENA, SOGAMOSO, BOYACA, COLOMBIA
#
# [2722 rows x 9 columns]

# %% [markdown]
# ## Georeferencing the addresses

# %% [markdown]
# We set the API key from Google Maps. (It has been deleted to avoid unwanted charges; ask Fabio if you need it).

# %%
# Commented to avoid unwanted executions
# API Key from GMaps
#gmaps = googlemaps.Client(key='')

# %%
# Functions that gives a match and lat/long in GMaps
def get_info_gmaps(busqueda):
    resultado = gmaps.geocode(busqueda)[0]
    match = resultado["formatted_address"]
    lat = resultado["geometry"]['location']["lat"]
    lng = resultado["geometry"]['location']["lng"]
    return match,lat,lng

# %% [markdown]
# And now, the magic of GMaps:

# %%
# Commented to avoid unwanted executions
# WARNING: This cell takes several minutes to run
#df["GEOREF"], df["LATITUD"], df["LONGITUD"] = zip(*df['DIRECCION_COMPLETA'].map(get_info_gmaps))

# %%
df
# Out:
#             RADICADO                       FECHA  \
# 0     20182000001012     27 - 10 - 2018 11:09:51
# 1     20182000001072     27 - 10 - 2018 11:32:35
# 2     20182000001312     11 - 12 - 2018 01:19:06
# 3     20182000000792     27 - 09 - 2018 03:38:10
# 4     20182000000172     15 - 08 - 2018 02:55:09
# ...              ...                         ...
# 2717  20191700061802  2019-05-03 09:46:20.619884
# 2718  20191700061812  2019-05-03 09:48:27.418469
# 2719  20191700062142  2019-05-03 14:31:18.900281
# 2720  20191700062312  2019-05-03 15:30:18.361842
# 2721  20191700062482  2019-05-06 09:52:22.710970
#
#                                                  ASUNTO      PAIS  \
# 0                                       AUTORIZACIÓN CX  COLOMBIA
# 1                                AUTORIZACIÓN AYUDAS DX  COLOMBIA
# 2                                          MEDICAMENTOS  COLOMBIA
# 3     QUE LA EPS LE BRINDE UNA ATENCIÓN INTEGRAL  YA...  COLOMBIA
# 4                                    ASIGNACION DE CITA  COLOMBIA
# ...                                                 ...       ...
# 2717  ACCION DE TUTELA No. 2019-0017\r\nACTE: MARIA ...  COLOMBIA
# 2718  ACCION DE TUTELA No. 2019-0019\r\nACTE: MARIA ...  COLOMBIA
# 2719                         SOLICITUD VISTA SANITARIA   COLOMBIA
# 2720  RESPUESTA A DERECHO DE PETICION RADICADO INVIM...  COLOMBIA
# 2721                        SOLICITUD VISITA SANITARIA   COLOMBIA
#
#                                   DIRECCION  \
# 0      CARRERA 34 # 15-145 SOGAMOSO, BOYACA
# 1     CALLE 58 DIAGONAL 11 SOGAMOSO, BOYACA
# 2     CARRERA 19 # 11 A 06 SOGAMOSO, BOYACA
# 3       CALLE 13 No 229-15 SOGAMOSO, BOYACA
# 4          calle 7A 14A-02 SOGAMOSO, BOYACA
# ...                                     ...
# 2717             CALLE 11 No. 9-30 OFC 202
# 2718              CALLE 11 No. 9-30 OFC 202
# 2719            CARRERA 13 No. 4-68 INT. 5
# 2720                       CRA 10 N 64-28
# 2721                  VEREDA SANTA HELENA
#
#                                            TEXTO_PQRSDF MUNICIPIO  \
# 0                      LA EPS NO AUTORIZA CX DE CADERAS  SOGAMOSO
# 1       LA EPS NO AUTORIZA LABORATORIOS,CONTROL POR CX.  SOGAMOSO
# 2           LA EPS NO AUTORIZA NMEDICAMENTO DABIGATRAN.  SOGAMOSO
# 3     SOLICITO  A  LA  EPS  ME  PRESTE  MANEJO  DOMI...  SOGAMOSO
# 4     LLEVO ESPERANDO CITA EN FAMEDIC Y OTORRINONLOG...  SOGAMOSO
# ...                                                 ...       ...
# 2717                                                NaN  SOGAMOSO
# 2718                                                NaN  SOGAMOSO
# 2719                                                NaN  SOGAMOSO
# 2720                                                NaN    BOGOTA
# 2721                                                NaN  SOGAMOSO
#
#      DEPARTAMENTO                                 DIRECCION_COMPLETA
# 0          BOYACA     CARRERA 34 # 15-145 SOGAMOSO, BOYACA, COLOMBIA
# 1          BOYACA    CALLE 58 DIAGONAL 11 SOGAMOSO, BOYACA, COLOMBIA
# 2          BOYACA    CARRERA 19 # 11 A 06 SOGAMOSO, BOYACA, COLOMBIA
# 3          BOYACA      CALLE 13 No 229-15 SOGAMOSO, BOYACA, COLOMBIA
# 4          BOYACA         calle 7A 14A-02 SOGAMOSO, BOYACA, COLOMBIA
# ...           ...                                                ...
# 2717       BOYACA  CALLE 11 No. 9-30 OFC 202, SOGAMOSO, BOYACA, C...
# 2718       BOYACA  CALLE 11 No. 9-30 OFC 202, SOGAMOSO, BOYACA, C...
# 2719       BOYACA  CARRERA 13 No. 4-68 INT. 5, SOGAMOSO, BOYACA, ...
# 2720         D.C.             CRA 10 N 64-28, BOGOTA, D.C., COLOMBIA
# 2721       BOYACA    VEREDA SANTA HELENA, SOGAMOSO, BOYACA, COLOMBIA
#
# [2722 rows x 9 columns]

# %% [markdown]
# We export this dataset with our results.

# %%
# Commented to avoid unwanted executions
#df.to_csv(r'/datasets/gdrive/DS4A - Team Project/data/geo_data.csv',encoding='UTF-8', index=False)

# %% [markdown]
# ## Visualizing the data

# %%
from folium.plugins import HeatMap

df = pd.read_csv('/datasets/gdrive/DS4A - Team Project/data/geo_data.csv', encoding="UTF-8")

# Creation of the base map, centered in Sogamoso
hmap = folium.Map(location=[5.7160848,-72.93112889999999], tiles = "Stamen Terrain", zoom_start=14)

# %%
# Creating a new df with only the relevant info and dropping NaNs
df_hm = df[["LATITUD", 'LONGITUD']]
#df_hm = df_hm[(df_hm['LATITUD'] != 5.7160848) | (df_hm['LONGITUD'] != -72.93112889999999)]
df_hm = df_hm.dropna(axis=0)

# %%
# List comprehension to make out list of lists for the heatmap
heat_data = [[row['LATITUD'],row['LONGITUD']] for index, row in df_hm.iterrows()]

# %%
# Create new layer with data and add it to the base map
hm_layer = HeatMap(heat_data, min_opacity=0.2, radius=17, blur=15, max_zoom=1, )
hm_layer.add_to(hmap)
# Display the map
hmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4727ad5edac4414ae6327f328e1815f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4727ad5edac4414ae6327f328e1815f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4727ad5edac4414ae6327f328e1815f7 = L.map(
#                 &quot;map_4727ad5edac4414ae6327f328e1815f7&quot;,
#                 {
#                     center: [5.7160848, -72.93112889999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_245646e4cc992a787be4ef89d2326074 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4727ad5edac4414ae6327f328e1815f7);
#
#
#             var heat_map_56786314c98327b292adcb3319223ef5 = L.heatLayer(
#                 [[5.7304346, -72.9406281], [5.758252, -72.906595], [5.7225077, -72.9249823], [5.5122029, -73.2458036], [5.5223537, -73.3699158], [5.7143675, -72.934711], [5.7149622, -72.9344642], [5.7347608, -72.93237640000001], [5.5602136, -73.20224809999999], [5.668615, -72.99625089999999], [5.7160848, -72.93112889999999], [5.668615, -72.99625089999999], [5.7449802, -72.9150097], [5.7232628, -72.9383582], [5.7788106, -73.1175758], [5.7169549, -72.9328651], [5.7094687, -72.93264099999999], [5.7112641, -72.94024619999999], [5.6973703, -72.9240001], [5.7170263, -72.93058839999999], [5.7160848, -72.93112889999999], [5.7170263, -72.93058839999999], [5.7042111, -72.9366042], [5.7152443, -72.9330646], [5.723759500000001, -72.9228868], [5.722007, -72.9215464], [5.7275795, -72.9276449], [5.7709277, -73.1151804], [5.7128557, -72.92548219999999], [5.7803702, -73.1174514], [5.771603199999999, -73.11559299999999], [5.7160848, -72.93112889999999], [5.7035224, -72.9363576], [5.5654192, -73.1868327], [5.7112641, -72.94024619999999], [5.7137387, -72.9318328], [4.5664481, -74.0906382], [5.7208397, -72.92205799999999], [5.512137099999999, -73.245722], [5.7136451, -72.9290846], [5.7112641, -72.94024619999999], [5.7260814, -72.9415527], [5.7555878, -72.906894], [5.7210946, -72.9107249], [5.710465, -72.9274835], [5.7158183, -72.9300118], [5.7803702, -73.1174514], [5.7160848, -72.93112889999999], [5.7160848, -72.93112889999999], [5.7112641, -72.94024619999999], [5.7308544, -72.9196984], [5.681441899999999, -72.9547548], [5.712048999999999, -72.9286049], [5.7120853, -72.93218139999999], [5.668615, -72.99625089999999], [5.7112641, -72.94024619999999], [5.7119216, -72.9441223], [5.7114676, -72.933437], [5.6577674, -72.9620448], [5.633409899999999, -72.91669], [5.7449802, -72.9150097], [5.710465, -72.9274835], [5.666877899999999, -72.9879981], [5.7160848, -72.93112889999999], [5.7709277, -73.1151804], [5.710465, -72.9274835], [5.7685621, -73.113705], [5.6672994, -72.9901871], [5.716230899999999, -72.9434533], [5.7230644, -72.9434095], [5.7299386, -72.92002180000001], [5.6708224, -72.9107185], [5.668615, -72.99625089999999], [5.7803702, -73.1174514], [5.6667963, -72.98878909999999], [5.7377781, -72.9178487], [5.7347608, -72.93237640000001], [5.7107968, -72.9294687], [5.746667, -72.9158386], [5.6464521, -73.1549619], [5.7109171, -72.9402554], [5.7356263, -72.9202167], [5.7112599, -72.94287450000002], [5.7230893, -72.9290697], [5.7076815, -72.9401029], [5.7087899, -72.9378988], [5.7347608, -72.93237640000001], [5.5654597, -73.1870563], [5.715186900000001, -72.9379277], [5.757947199999999, -72.905729], [5.7115054, -72.9437181], [5.7107604, -72.9427526], [5.7031487, -72.9426052], [5.8259528, -73.0360914], [5.781108199999999, -73.1172684], [5.7210668, -72.92190610000002], [5.7115054, -72.9437181], [5.7047504, -72.9349985], [5.7115054, -72.9437181], [5.7195035, -72.9333247], [5.670712, -72.99082489999999], [5.7223541, -72.9341862], [5.712510099999999, -72.9380401], [5.7282475, -72.9281889], [5.716765199999999, -72.9343675], [5.7223795, -72.93836809999999], [5.7115054, -72.9437181], [5.7055625, -72.9358495], [5.7115054, -72.9437181], [5.7115054, -72.9437181], [5.7119605, -72.9410029], [5.7160848, -72.93112889999999], [5.770309999999999, -74.03498], [5.7190215, -72.9406976], [5.7115054, -72.9437181], [5.7115054, -72.9437181], [5.7196776, -72.9307963], [5.5120384, -73.2458675], [5.7160848, -72.93112889999999], [5.7281808, -72.9356162], [5.7115054, -72.9437181], [5.712844, -72.9328692], [5.7115054, -72.9437181], [5.7160848, -72.93112889999999], [5.7247812, -72.9232639], [5.7115054, -72.9437181], [5.687107399999999, -72.94865779999999], [5.7115054, -72.9437181], [5.5654597, -73.1870563], [5.7399831, -72.9131318], [5.7115054, -72.9437

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=746f9757-a4f8-490f-a84c-875a1acb7471' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
